# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m = 3, 3

# %%
stack = []

# %%
def dfs (start):
    
    if len(stack) == m:
        print(''.join(map(str,stack)))
        return
    
    for i in range(start,n+1):
        stack.append(i)
        dfs(i)
        stack.pop()

# %%
dfs(1)
# Out:
# 111
# 112
# 113
# 122
# 123
# 133
# 222
# 223
# 233
# 333
