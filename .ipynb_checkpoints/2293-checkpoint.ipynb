# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,k = 3,10

# %%
coins =[1,2,5]

# %%
dp = [0 for i in range(k+1)]
dp[0] = 1

# %%
for coin in coins:
    for i in range(1, k+1):
        if i-coin >= 0:
            dp[i] += dp[i-1]

# %%
dp
# Out:
# [1, 1, 2, 3, 4, 9, 15, 22, 30, 39, 49]
